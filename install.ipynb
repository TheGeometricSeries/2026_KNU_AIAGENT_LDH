# %%
# %pip install dotenv pydantic langchain langchain-core langchain-groq
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
# %pip install -Uq langchain langchain-community langchain-core langchain-groq/opt/anaconda3/envs/ldh310/bin/python -m pip install -U langchain langchain-community langchain-core langchain-groq
# Out:
# [optparse.groups]Usage:[/]
#   /opt/anaconda3/envs/ldh310/bin/python -m pip install \[options] <requirement specifier> \[package-index-options] ...
#   /opt/anaconda3/envs/ldh310/bin/python -m pip install \[options] -r <requirements file> \[package-index-options] ...
#   /opt/anaconda3/envs/ldh310/bin/python -m pip install \[options] [-e] <vcs project url> ...
#   /opt/anaconda3/envs/ldh310/bin/python -m pip install \[options] [-e] <local project path> ...
#   /opt/anaconda3/envs/ldh310/bin/python -m pip install \[options] <archive url/path> ...
#
# no such option: -m
# Note: you may need to restart the kernel to use updated packages.
